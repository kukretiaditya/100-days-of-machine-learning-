# %%
# !pip install numpy pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (2.2.5)
# Requirement already satisfied: pandas in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (3.10.1)
# Requirement already satisfied: scikit-learn in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.scatter(df['cgpa'],df['iq'],c = df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 22   4.9  120.0
# 87   5.7  132.0
# 17   3.3  183.0
# 26   7.0  199.0
# 6    5.7  143.0
# ..   ...    ...
# 62   6.0  102.0
# 13   6.4  116.0
# 68   4.0   75.0
# 21   7.1  151.0
# 20   6.6  120.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 85   5.8  166.0
# 47   5.2  161.0
# 9    5.1   66.0
# 48   6.6  138.0
# 63   6.3  128.0
# 95   4.3  200.0
# 32   7.0  139.0
# 30   7.6  128.0
# 39   4.6  146.0
# 64   7.0   64.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.95622577, -0.06232932],
#        [-0.2579676 ,  0.24089441],
#        [-2.35274211,  1.52959525],
#        [ 0.87670193,  1.93389355],
#        [-0.2579676 ,  0.51884949],
#        [-1.82904849, -0.34028441],
#        [ 0.09116148,  0.24089441],
#        [-0.51981442,  0.31670034],
#        [-0.95622577, -1.55317932],
#        [ 1.13854874, -1.8311344 ],
#        [ 1.13854874,  0.36723763],
#        [ 0.44029057, -0.82038864],
#        [ 0.70213738, -0.82038864],
#        [ 0.70213738, -0.26447847],
#        [-0.78166123,  0.13981983],
#        [-0.2579676 ,  0.44304356],
#        [-1.04350804, -0.26447847],
#        [-0.2579676 ,  1.17583423],
#        [ 0.3530083 ,  0.4683122 ],
#        [-0.69437896, -0.82038864],
#        [ 0.26572603, -0.49189627],
#        [ 0.44029057,  0.19035712],
#        [ 0.78941965, -0.66877678],
#        [ 1.5749601 , -0.21394119],
#        [-0.51981442,  0.41777491],
#        [-1.04350804,  1.17583423],
#        [-2.17817757,  2.79302745],
#        [-0.51981442, -0.21394119],
#        [ 0.09116148,  0.84734186],
#        [ 0.00387921,  0.03874525],
#        [ 0.00387921, -1.4268361 ],
#        [-0.69437896,  2.56560965],
#        [-0.8689435 , -0.11286661],
#        [-0.95622577,  0.72099864],
#        [ 0.44029057, -2.15962677],
#        [-0.69437896, -0.31501576],
#        [ 0.44029057,  0.94841644],
#        [-0.08340306, -0.41609034],
#        [ 1.83680691,  0.67046135],
#        [-0.95622577,  1.85808762],
#        [-0.17068533,  0.49358085],
#        [-1.39263713, -2.03328355],
#        [ 0.61485511,  1.5043266 ],
#        [ 1.31311328,  0.19035712],
#        [ 0.78941965,  0.41777491],
#        [ 0.09116148, -0.49189627],
#        [ 2.01137145,  1.15056559],
#        [ 1.40039555, -0.84565728],
#        [ 1.74952464, -1.09834372],
#        [ 0.87670193,  1.3274461 ],
#        [ 0.87670193, -0.26447847],
#        [ 1.22583101,  0.24089441],
#        [ 0.17844375, -0.23920983],
#        [ 0.26572603,  0.11455119],
#        [ 1.31311328,  0.89787915],
#        [ 0.78941965,  0.39250627],
#        [ 0.00387921, -1.95747762],
#        [-1.04350804,  0.4683122 ],
#        [-0.95622577,  0.82207322],
#        [ 0.09116148, -1.04780644],
#        [-1.13079031, -1.78059711],
#        [-0.51981442, -0.39082169],
#        [-0.60709669, -0.21394119],
#        [-0.8689435 , -0.79512   ],
#        [-1.39263713,  0.67046135],
#        [-0.78166123,  1.35271474],
#        [-0.95622577,  0.29143169],
#        [ 1.83680691,  1.1000283 ],
#        [ 0.00387921,  0.67046135],
#        [ 0.70213738,  0.4683122 ],
#        [-1.13079031, -0.89619457],
#        [ 1.31311328, -1.55317932],
#        [-0.69437896,  0.24089441],
#        [-1.13079031, -0.03706068],
#        [ 1.13854874, -0.92146322],
#        [-1.74176621, -0.5677022 ],
#        [ 2.18593599, -0.06232932],
#        [ 0.61485511,  0.79680457],
#        [ 0.09116148, -1.45210474],
#        [-0.8689435 , -1.50264203],
#        [ 0.9639842 , -1.88167169],
#        [-1.04350804,  1.02422237],
#        [-0.60709669, -0.03706068],
#        [ 0.70213738,  0.01347661],
#        [ 1.13854874, -0.1634039 ],
#        [ 0.00387921, -0.51716491],
#        [ 0.3530083 , -0.1634039 ],
#        [-1.74176621, -1.1994183 ],
#        [ 0.9639842 ,  0.72099864],
#        [ 0.52757284, -0.06232932]])

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[-0.17068533,  1.1000283 ],
#        [-0.69437896,  0.97368508],
#        [-0.78166123, -1.4268361 ],
#        [ 0.52757284,  0.39250627],
#        [ 0.26572603,  0.13981983],
#        [-1.4799194 ,  1.95916219],
#        [ 0.87670193,  0.41777491],
#        [ 1.40039555,  0.13981983],
#        [-1.21807259,  0.59465542],
#        [ 0.87670193, -1.47737338]])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
#model training 
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 85    1
# 47    0
# 9     0
# 48    1
# 63    1
# 95    0
# 32    1
# 30    1
# 39    0
# 64    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (2.2.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\suneel\anaconda3\envs\campusx\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend = 2)
# Out:
# <Axes: >

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
